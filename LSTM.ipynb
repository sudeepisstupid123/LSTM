# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
model = keras.Sequential()
model.add(layers.LSTM(64, input_shape=(None, 28)))
model.add(layers.BatchNormalization())
model.add(layers.Dense(10))
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                23808
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 24714 (96.54 KB)
# Trainable params: 24586 (96.04 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________
# None

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train/255.0, x_test/255.0
x_validate, y_validate = x_test[:-10], y_test[:-10]
x_test, y_test = x_test[-10:], y_test[-10:]

model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer="sgd",
    metrics=["accuracy"],
)
model.fit(
    x_train, y_train, validation_data=(x_test, y_test), batch_size=64, epochs=1
)
model.fit(
    x_train, y_train, validation_data=(x_validate, y_validate), batch_size=64, epochs=10
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 938/938 [==============================] - 26s 24ms/step - loss: 0.9889 - accuracy: 0.6875 - val_loss: 0.2854 - val_accuracy: 0.8000
# Epoch 1/10
# 938/938 [==============================] - 19s 21ms/step - loss: 0.4022 - accuracy: 0.8798 - val_loss: 0.6723 - val_accuracy: 0.8082
# Epoch 2/10
# 938/938 [==============================] - 20s 21ms/step - loss: 0.2515 - accuracy: 0.9250 - val_loss: 0.1815 - val_accuracy: 0.9429
# Epoch 3/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.1926 - accuracy: 0.9415 - val_loss: 0.1393 - val_accuracy: 0.9591
# Epoch 4/10
# 938/938 [==============================] - 20s 21ms/step - loss: 0.1589 - accuracy: 0.9516 - val_loss: 0.1405 - val_accuracy: 0.9551
# Epoch 5/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.1391 - accuracy: 0.9586 - val_loss: 0.2511 - val_accuracy: 0.9140
# Epoch 6/10
# 938/938 [==============================] - 20s 22ms/step - loss: 0.1248 - accuracy: 0.9626 - val_loss: 0.0982 - val_accuracy: 0.9678
# Epoch 7/10
# 938/938 [==============================] - 21s 22ms/step - loss: 0.1136 - accuracy: 0.9652 - val_loss: 0.1379 - val_accuracy: 0.9545
# Epoch 8/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.1039 - accuracy: 0.9679 - val_loss: 0.1326 - val_accuracy: 0.9572
# Epoch 9/10
# 938/938 [==============================] - 20s 21ms/step - loss: 0.0986 - accuracy: 0.9696 - val_loss: 0.0871 - val_accuracy: 0.9714
# Epoch 10/10
# 938/938 [==============================] - 19s 20ms/step - loss: 0.0930 - accuracy: 0.9707 - val_loss: 0.0816 - val_accuracy: 0.9735

# %%
for i in range(10):
    result = tf.argmax(model.predict(tf.expand_dims(x_test[i], 0)), axis=1)
    print(result.numpy(), y_test[i])
# Out:
# 1/1 [==============================] - 0s 469ms/step
# [7] 7
# 1/1 [==============================] - 0s 22ms/step
# [8] 8
# 1/1 [==============================] - 0s 22ms/step
# [9] 9
# 1/1 [==============================] - 0s 21ms/step
# [0] 0
# 1/1 [==============================] - 0s 22ms/step
# [1] 1
# 1/1 [==============================] - 0s 21ms/step
# [2] 2
# 1/1 [==============================] - 0s 22ms/step
# [3] 3
# 1/1 [==============================] - 0s 21ms/step
# [4] 4
# 1/1 [==============================] - 0s 21ms/step
# [5] 5
# 1/1 [==============================] - 0s 21ms/step
# [6] 6
